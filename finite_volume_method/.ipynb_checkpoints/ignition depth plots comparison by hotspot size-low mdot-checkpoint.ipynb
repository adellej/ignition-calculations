# %%
from finite_volume import Diffuse
import numpy as np
from scipy import integrate
from scipy import interpolate
from matplotlib import pyplot as plt
from matplotlib.colors import LogNorm, Normalize
import scipy.linalg
import color
import cmasher as cmr
from kepdump import load
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,
                               AutoMinorLocator)

# %%
# read in data to dict:

Temp_data_hot = {}
x_data_hot = {}
z_data_hot = {}
rho_data_hot = {}
ycol_data_hot = {}


sizes = [0.0001,0.001, 0.005, 0.01,0.1, 0.3, 1.0, 1.5, 2.0]
lengths = [0.004, 0.04, 0.4, 1.2, 2.4, 4.0, 5.2, 6.4, 8.0]
names = ['run5_HS_size_1cm','run5_HS_size_1m','run5_HS_size_5m','run5_HS_size_10m']#,'run5_HS_size_100m', 'run5_HS_size_300m', 'run5_HS_size_600m']
#,\
      #   'run5_HS_size_1km', 'run5_HS_size_1.5km', 'run5_HS_size_2km']
temps =[1e8, 5e7]
qb=1

for i in range(len(names)):
    D = Diffuse(Nx=200,
        Nz=80,
        Lx=lengths[i]*1e5,
        Lz=600,
        Tcrust=1e7,
        Thotspot=1e7,
        Ttop=1e6,
         bb_flag='bb',
         Fbase=1.0e21,
        hsize=sizes[i]*400/lengths[i],
         tol=1e-6,
         op=1.0,
         maxIter=300,
         run_name="17480_1e8",
         rhoflag="fit",
         coord="cylindrical",
         kappa_path='/Users/adelle/Documents/ignition_calculations/cylindrical_coords/finite_volume_method/kappa.npz',
         dump_path=f'/Users/adelle/Documents/ignition_calculations/kepler/run5/h#946')
    with open(f"/Users/adelle/Documents/ignition_calculations/cylindrical_coords/Alex/heat/heat_substrate/heat/data/data_solutiontemp_run{names[i]}_qb{qb}_hs{temps[0]}.txt") as f:
            lines = (line for line in f if not line.startswith("#"))
            Temp_data_hot[f'{names[i]}'] = np.loadtxt(lines, delimiter=" ", skiprows=1)
    x_data_hot[f'{names[i]}'] = D.x
    z_data_hot[f'{names[i]}'] = D.z
    rhovals2 = -1 * D.rhoz 
    rho_data_hot[f'{names[i]}'] = rhovals2
    ycol_data_hot[f'{names[i]}'] = integrate.cumtrapz(rhovals2[::-1], D.z[::-1], initial=1e-3)[::-1]
# Out:
# 4274567.378402097 3784549.677601888
# 4274567.378402097 3784549.677601888
# 4274567.378402097 3784549.677601888
# 4274567.378402097 3784549.677601888
# 4274567.378402097 3784549.677601888
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-7398399c6fce> in <module>
#      35          kappa_path='/Users/adelle/Documents/ignition_calculations/cylindrical_coords/finite_volume_method/kappa.npz',
#      36          dump_path=f'/Users/adelle/Documents/ignition_calculations/kepler/run5/h#946')
# ---> 37     with open(f"/Users/adelle/Documents/ignition_calculations/cylindrical_coords/Alex/heat/heat_substrate/heat/data/data_solutiontemp_run{names[i]}_qb{qb}_hs{temps[0]}.txt") as f:
#      38             lines = (line for line in f if not line.startswith("#"))
#      39             Temp_data_hot[f'{names[i]}'] = np.loadtxt(lines, delimiter=" ", skiprows=1)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/adelle/Documents/ignition_calculations/cylindrical_coords/Alex/heat/heat_substrate/heat/data/data_solutiontemp_runrun5_HS_size_100m_qb1_hs100000000.0.txt'

# %%
name = 'run5_nohotspot'

D = Diffuse(Nx=200,
        Nz=80,
        Lx=0.01*1e5,
        Lz=600,
        Tcrust=1e7,
        Thotspot=1e7,
        Ttop=1e6,
         bb_flag='bb',
         Fbase=1.0e21,
        hsize=0,
         tol=1e-6,
         op=1.0,
         maxIter=300,
         run_name="17480_1e8",
         rhoflag="fit",
         coord="cylindrical",
         kappa_path='/Users/adelle/Documents/ignition_calculations/cylindrical_coords/finite_volume_method/kappa.npz',
         dump_path=f'/Users/adelle/Documents/ignition_calculations/kepler/run5/h#946')
with open(f"/Users/adelle/Documents/ignition_calculations/cylindrical_coords/Alex/heat/data/data_solutiontemp_run{name}_qb{qb}_hs{temps[0]}.txt") as f:
            lines = (line for line in f if not line.startswith("#"))
            Temp_data = np.loadtxt(lines, delimiter=" ", skiprows=1)
x_data = D.x
z_data = D.z
rhovals2 = -1 * D.rhoz 
rho_data = rhovals2
ycol_data = integrate.cumtrapz(rhovals2[::-1], D.z[::-1], initial=1e-3)[::-1]
# Out:
# 4274567.378402097 3784549.677601888

# %%
for j in range(len(names)):
    for i in range(0,len(z_data_hot[f'{names[j]}'])-1):
        plt.plot(x_data_hot[f'{names[j]}'][1:]/1e5 , Temp_data_hot[f'{names[j]}'].transpose()[:,i])

    plt.xlabel('x')
    plt.ylabel('T (K)')

    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-ae3b0dc6069c> in <module>
#       1 for j in range(len(names)):
# ----> 2     for i in range(0,len(z_data_hot[f'{names[j]}'])-1):
#       3         plt.plot(x_data_hot[f'{names[j]}'][1:]/1e5 , Temp_data_hot[f'{names[j]}'].transpose()[:,i])
#       4
#       5     plt.xlabel('x')
#
# KeyError: 'run5_HS_size_5m'

# %%
import color
c = color.IsoColorBlind(5)
f = plt.figure(figsize=(6,4))
ax = f.add_subplot(111)
labels = ['1cm', '1m', '5m', '10m', '100m', '300m']
for j in range(5):  
        plt.plot(x_data_hot[f'{names[j]}'][1:]/x_data_hot[f'{names[j]}'][-1] ,\
                 Temp_data_hot[f'{names[j]}'].transpose()[:,10], label=f'{labels[j]}', color=c[j])

# labels = ['1cm', '1m', '5m', '10m', '100m']
# for i in range(0,len(z_data_hot[f'{names[j]}'])-1):
#     for j in range(5):  
#         plt.plot(x_data_hot[f'{names[j]}'][1:]/x_data_hot[f'{names[j]}'][-1] ,\
#                  Temp_data_hot[f'{names[j]}'].transpose()[:,i], label=None, color=c[j],alpha=0.5)

plt.xlabel('$x$ (scaled)', fontsize=12)
plt.ylabel('log $T$ (K)', fontsize=12)
plt.legend(loc='best', fontsize=12)

ax.tick_params(axis='both', which='major', labelsize=12)
ax.tick_params(axis='both', which='minor', labelsize=12)
#ax.set_yticklabels('')
ax.xaxis.set_minor_locator(AutoMinorLocator())
ax.yaxis.set_minor_locator(AutoMinorLocator())

plt.savefig('heating_HSsizes_cyl_base_run5_substrate.pdf')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-f576393042e6> in <module>
#       5 labels = ['1cm', '1m', '5m', '10m', '100m', '300m']
#       6 for j in range(5):
# ----> 7         plt.plot(x_data_hot[f'{names[j]}'][1:]/x_data_hot[f'{names[j]}'][-1] ,\
#       8                  Temp_data_hot[f'{names[j]}'].transpose()[:,10], label=f'{labels[j]}', color=c[j])
#       9
#
# KeyError: 'run5_HS_size_5m'

# %%
for j in range(5):  
    plt.plot(x_data_hot[f'{names[j]}'][1:]/1e5 , Temp_data_hot[f'{names[j]}'].transpose()[:,10], label=f'{names[j]}')
# for j in range(len(names)):  
#     plt.plot(x_data_hot[f'{names[j]}'][1:]/1e5 , Temp_data_hot[f'{names[j]}'].transpose()[:,5])
plt.xlabel('x')
plt.ylabel('10th base T (K)')
plt.legend(loc='best')
plt.savefig('heating_HSsizes_equator.pdf')
plt.show()

# %%
for j in range(5):  
    plt.plot(x_data_hot2[f'{names2[j]}'][1:]/1e5 , Temp_data_hot2[f'{names2[j]}'].transpose()[:,10], ls='--', label=f'{names2[j]}equator')
# for j in range(len(names)):  
#     plt.plot(x_data_hot[f'{names[j]}'][1:]/1e5 , Temp_data_hot[f'{names[j]}'].transpose()[:,5])
plt.xlabel('x')
plt.ylabel('10th base T (K)')
plt.legend(loc='best')
plt.savefig('heating_HSsizes_equator_lowgrav.pdf')
plt.show()

# %%
print(np.shape(z_data_hot['run5_HS_size_1cm']), np.shape(Temp_data_hot['run5_HS_size_1cm']))
# Out:
# (585,) (634, 200)

# %%
# import color
f = plt.figure(figsize=(8, 4))
name = 'run5_HS_size_1cm'

T = Temp_data_hot[f'{name}'][634-585:, ]

zplot, xplot = np.meshgrid(z_data_hot[f'{name}'], np.hstack((-x_data_hot[f'{name}'][1:][::-1]/1e5, x_data_hot[f'{name}']/1e5)))
kap_in = np.vstack((T.transpose()[::-1, :], T.transpose()))

ax = f.add_subplot(111)
cmap = plt.cm.magma
#color.colormap('magma_r')
#cmap = color.WaveFilter(cmap, nwaves = 40, amplitude=0.2)
#cmap = color.ColorScaleGamma(cmap, 10.)

# cmap = color.ColorBlindRainbow()
# colourMap = color.WaveFilter(cmap, nwaves = 40, amplitude=0.2)
# ax.set_aspect('equal')
# kappa = np.zeros((len(T_p_in[:, 0]), len(T_p_in[0, :])))
# for i in range(0, len(T_p_in[:, 0])):
#     for j in range(0, len(T_p_in[0, :])):
#         kappa[i, j] = D.get_kappa(T_p_in[i,j], D.rhoc[j])
cm = ax.pcolormesh(
    xplot, zplot, (kap_in), cmap=cmap)#, vmin=8.1, vmax=8.3)#, shading='gouraud'
  # np.log10(
# np.power(T_p, 0.25)),cmap=colourMap, norm=norm)
# Set Colorbar
cbar = f.colorbar(cm, orientation='vertical')
cbar.set_label(label=r'log $T$', size=12)
plt.ylabel("$r$ (cm)", fontsize=12)
plt.xlabel("$x$ (km)",fontsize=12)


ax.tick_params(axis='both', which='major', labelsize=12)
ax.tick_params(axis='both', which='minor', labelsize=12)
cbar.ax.tick_params(labelsize=12)

#ax.set_yticklabels('')
ax.xaxis.set_minor_locator(AutoMinorLocator())
ax.yaxis.set_minor_locator(AutoMinorLocator())

#for i in range(len(x_data_hot[f'{name}'])):
    #plt.axvline(x_data_hot[f'{name}'][i]/1e5, ls='-', color='grey')

#plt.axis([0,0.,0,None])

plt.tight_layout()
#plt.savefig('HS_5m_run5.png')
plt.show()
plt.close()
# Out:
# <ipython-input-13-5368b9ea786f>:23: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   cm = ax.pcolormesh(

# %%
import color
f = plt.figure(figsize=(8, 4))
name = 'run5_nohotspot'

zplot, xplot = np.meshgrid(z_data, np.hstack((-x_data[1:][::-1]/1e5, x_data/1e5)))
kap_in = np.vstack((Temp_data.transpose()[::-1, :], Temp_data.transpose()))

ax = f.add_subplot(111)
cmap = plt.cm.magma
#color.colormap('magma_r')
#cmap = color.WaveFilter(cmap, nwaves = 40, amplitude=0.2)
#cmap = color.ColorScaleGamma(cmap, 10.)

# cmap = color.ColorBlindRainbow()
# colourMap = color.WaveFilter(cmap, nwaves = 40, amplitude=0.2)
# ax.set_aspect('equal')
# kappa = np.zeros((len(T_p_in[:, 0]), len(T_p_in[0, :])))
# for i in range(0, len(T_p_in[:, 0])):
#     for j in range(0, len(T_p_in[0, :])):
#         kappa[i, j] = D.get_kappa(T_p_in[i,j], D.rhoc[j])
cm = ax.pcolormesh(
    xplot, zplot, (kap_in), cmap=cmap, vmin=8.1, vmax=8.3)#, shading='gouraud'
  # np.log10(
# np.power(T_p, 0.25)),cmap=colourMap, norm=norm)
# Set Colorbar
cbar = f.colorbar(cm, orientation='vertical')
cbar.set_label(label=r'log $T$', size=12)
plt.ylabel("$r$ (cm)", fontsize=12)
plt.xlabel("$x$ (km)",fontsize=12)


ax.tick_params(axis='both', which='major', labelsize=12)
ax.tick_params(axis='both', which='minor', labelsize=12)
cbar.ax.tick_params(labelsize=12)

#ax.set_yticklabels('')
ax.xaxis.set_minor_locator(AutoMinorLocator())
ax.yaxis.set_minor_locator(AutoMinorLocator())

#for i in range(len(x_data_hot[f'{name}'])):
    #plt.axvline(x_data_hot[f'{name}'][i]/1e5, ls='-', color='grey')

#plt.axis([0,1.0,0,None])

plt.tight_layout()
plt.savefig('HS_none_run5.png')
plt.show()
plt.close()
