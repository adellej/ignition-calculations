# %%
from finite_volume import Diffuse
import numpy as np
from scipy import integrate
from scipy import interpolate
from matplotlib import pyplot as plt
from matplotlib.colors import LogNorm, Normalize
import scipy.linalg
import color
import cmasher as cmr
from kepdump import load
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,
                               AutoMinorLocator)

# %%
# read in data to dict:

Temp_data = {}
x_data = {}
z_data = {}
ycol_data = {}

Temp_data_hot = {}
x_data_hot = {}
z_data_hot = {}
rho_data_hot = {}
ycol_data_hot = {}


dump_list = ['h#301', 'h#303', 'h#306', 'h#309', 'h#321']
Thot = 1.7e8
qb = 1
names = ['run3_40sec','run3_30sec', 'run3_20sec','run3_10sec', 'run3_0sec']

for i in range(len(names)):
    D = Diffuse(Nx=200,
        Nz=80,
        Lx=100000,
        Lz=600,
        Tcrust=1e7,
        Thotspot=Thot,
        Ttop=1e6,
         bb_flag='bb',
         Fbase=1.0e21,
        hsize=20,
         tol=1e-6,
         op=1.0,
         maxIter=300,
         run_name="17480_1e8",
         rhoflag="fit",
         coord="cylindrical",
         kappa_path='/Users/adelle/Documents/ignition_calculations/cylindrical_coords/finite_volume_method/kappa.npz',
         dump_path=f'/Users/adelle/Documents/ignition_calculations/kepler/run3/{dump_list[i]}')
    with open(f"/Users/adelle/Documents/ignition_calculations/cylindrical_coords/Alex/heat/data/data_solutiontemp_run{names[i]}_qb{qb}_Thot{Thot}_pole.txt") as f:
            lines = (line for line in f if not line.startswith("#"))
            Temp_data_hot[f'{names[i]}'] = np.loadtxt(lines, delimiter=" ", skiprows=1)
    x_data_hot[f'{names[i]}'] = D.x
    z_data_hot[f'{names[i]}'] = D.z
    rhovals2 = -1 * D.rhoz 
    rho_data_hot[f'{names[i]}'] = rhovals2
    ycol_data_hot[f'{names[i]}'] = integrate.cumtrapz(rhovals2[::-1], D.z[::-1], initial=1e-3)[::-1]
# Out:
# 2376215.150212959 2333698.4280111417
# Height is: 733.884814332705
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-ef0f57493d84> in <module>
#      19
#      20 for i in range(len(names)):
# ---> 21     D = Diffuse(Nx=200,
#      22         Nz=80,
#      23         Lx=100000,
#
# ~/Documents/ignition_calculations/cylindrical_coords/finite_volume_method/finite_volume.py in __init__(self, Nx, Nz, Lx, Lz, Tcrust, Thotspot, Ttop, bb_flag, Fbase, hsize, tol, op, maxIter, run_name, rhoflag, coord, kappa_path, dump_path, substrate)
#     288             #load iron comp kappa table
#     289             self.kappa_path_Fe = kappa_path[1]
# --> 290             data = np.load(self.kappa_path_Fe, allow_pickle=True)
#     291             tem = np.power(data['tem'], 4)
#     292             den = data['den']
#
# ~/miniconda3/lib/python3.8/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     414             own_fid = False
#     415         else:
# --> 416             fid = stack.enter_context(open(os_fspath(file), "rb"))
#     417             own_fid = True
#     418
#
# FileNotFoundError: [Errno 2] No such file or directory: 'U'

# %%
# read in data to dict:

Temp_data_med = {}
x_data_med = {}
z_data_med = {}
rho_data_med = {}
ycol_data_med = {}


dump_list = ['h#301', 'h#303', 'h#306', 'h#309', 'h#321']
Thot = 8e7
qb = 1
names = ['run3_40sec','run3_30sec', 'run3_20sec','run3_10sec', 'run3_0sec']

for i in range(len(names)):
    D = Diffuse(Nx=200,
        Nz=80,
        Lx=100000,
        Lz=600,
        Tcrust=1e7,
        Thotspot=Thot,
        Ttop=1e6,
         bb_flag='bb',
         Fbase=1.0e21,
        hsize=20,
         tol=1e-6,
         op=1.0,
         maxIter=300,
         run_name="17480_1e8",
         rhoflag="fit",
         coord="cylindrical",
         kappa_path=('/Users/adelle/Documents/ignition_calculations/cylindrical_coords/finite_volume_method/kappa.npz',\
            'kappa_fe.npz'),
         dump_path=f'/Users/adelle/Documents/ignition_calculations/kepler/run3/{dump_list[i]}',
    substrate = True)
    with open(f"/Users/adelle/Documents/ignition_calculations/cylindrical_coords/Alex/heat/data/data_solutiontemp_run{names[i]}_qb{qb}_Thot{Thot}_pole.txt") as f:
            lines = (line for line in f if not line.startswith("#"))
            Temp_data_med[f'{names[i]}'] = np.loadtxt(lines, delimiter=" ", skiprows=1)
    x_data_med[f'{names[i]}'] = D.x
    z_data_med[f'{names[i]}'] = D.z
    rhovals2 = -1 * D.rhoz 
    rho_data_med[f'{names[i]}'] = rhovals2
    ycol_data_med[f'{names[i]}'] = integrate.cumtrapz(rhovals2[::-1], D.z[::-1], initial=1e-3)[::-1]
# Out:
# 2376215.150212959 2333698.4280111417
# Height is: 733.884814332705
# 2376221.1643553004 2333686.6048111552
# Height is: 734.6043348193634
# 2375962.943562308 2333364.5003882335
# Height is: 736.1830727857305
# 2375238.4152468825 2332524.4850125564
# Height is: 738.0702350584324
# 2371033.354564158 2327220.8449996514
# Height is: 743.9187377245398
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-f47b24d531d5> in <module>
#      34          dump_path=f'/Users/adelle/Documents/ignition_calculations/kepler/run3/{dump_list[i]}',
#      35     substrate = True)
# ---> 36     with open(f"/Users/adelle/Documents/ignition_calculations/cylindrical_coords/Alex/heat/data/data_solutiontemp_run{names[i]}_qb{qb}_Thot{Thot}_pole.txt") as f:
#      37             lines = (line for line in f if not line.startswith("#"))
#      38             Temp_data_med[f'{names[i]}'] = np.loadtxt(lines, delimiter=" ", skiprows=1)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/adelle/Documents/ignition_calculations/cylindrical_coords/Alex/heat/data/data_solutiontemp_runrun3_0sec_qb1_Thot80000000.0_pole.txt'

# %%
# read in data to dict:

Temp_data_cold = {}
x_data_cold = {}
z_data_cold = {}
rho_data_cold = {}
ycol_data_cold = {}


dump_list = ['h#301', 'h#303', 'h#306', 'h#309', 'h#321']
Thot = 3e7
qb = 1
names = ['run3_40sec','run3_30sec', 'run3_20sec','run3_10sec', 'run3_0sec']

for i in range(len(names)):
    D = Diffuse(Nx=200,
        Nz=80,
        Lx=100000,
        Lz=600,
        Tcrust=1e7,
        Thotspot=Thot,
        Ttop=1e6,
         bb_flag='bb',
         Fbase=1.0e21,
        hsize=20,
         tol=1e-6,
         op=1.0,
         maxIter=300,
         run_name="17480_1e8",
         rhoflag="fit",
         coord="cylindrical",
         kappa_path='/Users/adelle/Documents/ignition_calculations/cylindrical_coords/finite_volume_method/kappa.npz',
         dump_path=f'/Users/adelle/Documents/ignition_calculations/kepler/run3/{dump_list[i]}')
    with open(f"/Users/adelle/Documents/ignition_calculations/cylindrical_coords/Alex/heat/data/data_solutiontemp_run{names[i]}_qb{qb}_Thot{Thot}_pole.txt") as f:
            lines = (line for line in f if not line.startswith("#"))
            Temp_data_cold[f'{names[i]}'] = np.loadtxt(lines, delimiter=" ", skiprows=1)
    x_data_cold[f'{names[i]}'] = D.x
    z_data_cold[f'{names[i]}'] = D.z
    rhovals2 = -1 * D.rhoz 
    rho_data_cold[f'{names[i]}'] = rhovals2
    ycol_data_cold[f'{names[i]}'] = integrate.cumtrapz(rhovals2[::-1], D.z[::-1], initial=1e-3)[::-1]
# Out:
# 1756167.259167886 1457950.3874951988
# 1755491.3372474003 1457335.3508226848
# 1752924.8160522995 1455023.2035791315
# 1748522.5397835043 1451064.6762261994
# 1699793.2721917422 1418065.4643240445
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-29-e2ace8efadfc> in <module>
#      32          kappa_path='/Users/adelle/Documents/ignition_calculations/cylindrical_coords/finite_volume_method/kappa.npz',
#      33          dump_path=f'/Users/adelle/Documents/ignition_calculations/kepler/run3/{dump_list[i]}')
# ---> 34     with open(f"/Users/adelle/Documents/ignition_calculations/cylindrical_coords/Alex/heat/data/data_solutiontemp_run{names[i]}_qb{qb}_Thot{Thot}_pole.txt") as f:
#      35             lines = (line for line in f if not line.startswith("#"))
#      36             Temp_data_cold[f'{names[i]}'] = np.loadtxt(lines, delimiter=" ", skiprows=1)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/adelle/Documents/ignition_calculations/cylindrical_coords/Alex/heat/data/data_solutiontemp_runrun3_0sec_qb1_Thot30000000.0_pole.txt'

# %%
f = plt.figure(figsize=(10, 5))

zplot, xplot = np.meshgrid(z_data_hot['run3_40sec'], np.hstack((-x_data_hot['run3_40sec'][1:][::-1]/1e5, D.x/1e5)))
kap_in = np.vstack((Temp_data_hot['run3_40sec'].transpose()[::-1, :], Temp_data_hot['run3_40sec'].transpose()))

ax = f.add_subplot(111)
colourMap = plt.cm.magma
# cmap = color.ColorBlindRainbow()
# colourMap = color.WaveFilter(cmap, nwaves = 40, amplitude=0.2)
# ax.set_aspect('equal')
# kappa = np.zeros((len(T_p_in[:, 0]), len(T_p_in[0, :])))
# for i in range(0, len(T_p_in[:, 0])):
#     for j in range(0, len(T_p_in[0, :])):
#         kappa[i, j] = D.get_kappa(T_p_in[i,j], D.rhoc[j])
cm = ax.pcolormesh(
    xplot, zplot, (kap_in), cmap=colourMap
)  # np.log10(
# np.power(T_p, 0.25)),cmap=colourMap, norm=norm)
# Set Colorbar
cbar = f.colorbar(cm, orientation='vertical')
cbar.set_label(label=r'log $T$', size=12)
plt.ylabel("$r$ (cm)", fontsize=12)
plt.xlabel("$x$ (km)",fontsize=12)


ax.tick_params(axis='both', which='major', labelsize=12)
ax.tick_params(axis='both', which='minor', labelsize=8)
cbar.ax.tick_params(labelsize=12)

plt.tight_layout()
plt.show()
plt.close()

# %%
import color
c = color.IsoColorBlind(4)
fig, ax = plt.subplots(figsize=[8, 5])
# define columns to plot:
names = ['run3_40sec','run3_30sec', 'run3_20sec', 'run3_10sec']

ncols = 10
cols = np.arange(0, D.Nx, (D.Nx + 1) / ncols, dtype=int)

# ----------------- hot --------------------------
j=0
Ts = {}
Tign = {}
for i in cols:
    Ts[f"{i}"] = 10**Temp_data_hot[f'{names[j]}'].transpose()[i, :]
    Tign[f"{i}"] = np.array(D.Tign(ycol_data_hot[f'{names[j]}'] / 1e8, 10**Temp_data_hot[f'{names[j]}'].transpose()[i,:], rho_data_hot[f'{names[j]}']))
plt.plot(ycol_data_hot[f'{names[j]}'][:-1]/1e8, Tign[f"{i}"]/1e8, ls="-", label="ignition", color="k")

for j in range(0,3):
    ncols = 10
    cols = np.arange(0, D.Nx, (D.Nx + 1) / ncols, dtype=int)
    cols2 = cols * D.dx
    # get column depths, temperatures and ignition temperatures for these columns
    Ts = {}
    
    for i in cols:
        Ts[f"{i}"] = 10**Temp_data_hot[f'{names[j]}'].transpose()[i, :]
    i=9
    plt.plot(
        ycol_data_hot[f'{names[j]}'][1:]/1e8, Ts[f"{cols[i]}"]/1e8, color=c[j],ls='-'
    ) #label=f"column {cols2[i]}/{D.Lx}"
    i = 0
    plt.plot(
            ycol_data_hot[f'{names[j]}'][1:]/1e8, Ts[f"{cols[i]}"]/1e8, color=c[j], label = f'{names[j]}, hot', ls = '-.'
        #label=r'$T_{HS}=1.5\times10^8$ K, pole', ls='-.'
        )
    
plt.legend(loc="best",fontsize=10, ncol=2)
# plt.xscale("log")
# plt.yscale("log")
plt.xlabel(r"$y$ (10$^8$ g cm$^{-2}$)",fontsize=12)
plt.ylabel("$T$ (10$^8$ K)", fontsize=12)
plt.axis([-0.2,3.8,-0.2,2.5])
#plt.axis([0.8,1.2,1.4,1.9])
ax.tick_params(axis='both', which='major', labelsize=12)
ax.tick_params(axis='both', which='minor', labelsize=8)

#ax.xaxis.set_major_locator(MultipleLocator(0.2e8))
#ax.xaxis.set_major_formatter(FormatStrFormatter('%d'))
# For the minor ticks, use no labels; default NullFormatter.
ax.xaxis.set_minor_locator(AutoMinorLocator())
ax.yaxis.set_minor_locator(AutoMinorLocator())

plt.savefig('time_comparison_hot_run3.pdf')

plt.show()
    
# ----------------- med --------------------------
fig, ax = plt.subplots(figsize=[8, 5])
j=0
Ts = {}
Tign = {}
for i in cols:
    Ts[f"{i}"] = 10**Temp_data_med[f'{names[j]}'].transpose()[i, :]
    Tign[f"{i}"] = np.array(D.Tign(ycol_data_med[f'{names[j]}'] / 1e8, 10**Temp_data_med[f'{names[j]}'].transpose()[i,:], rho_data_med[f'{names[j]}']))
plt.plot(ycol_data_med[f'{names[j]}'][:-1]/1e8, Tign[f"{i}"]/1e8, ls="--", label="ignition", color="k")

for j in range(0,4):
    ncols = 10
    cols = np.arange(0, D.Nx, (D.Nx + 1) / ncols, dtype=int)
    cols2 = cols * D.dx
    # get column depths, temperatures and ignition temperatures for these columns
    Ts = {}
    
    for i in cols:
        Ts[f"{i}"] = 10**Temp_data_med[f'{names[j]}'].transpose()[i, :]
    i=9
    plt.plot(
        ycol_data_med[f'{names[j]}'][1:]/1e8, Ts[f"{cols[i]}"]/1e8, color=c[j],ls='-'
    ) #label=f"column {cols2[i]}/{D.Lx}"
    i = 0
    plt.plot(
            ycol_data_med[f'{names[j]}'][1:]/1e8, Ts[f"{cols[i]}"]/1e8, color=c[j], label = f'{names[j]}, med', ls = '--'
        #label=r'$T_{HS}=1.5\times10^8$ K, pole', ls='-.'
        )
    
plt.legend(loc="best",fontsize=10, ncol=2)
# plt.xscale("log")
# plt.yscale("log")
plt.xlabel(r"$y$ (10$^8$ g cm$^{-2}$)",fontsize=12)
plt.ylabel("$T$ (10$^8$ K)", fontsize=12)
plt.axis([-0.2,3.8,-0.2,2.5])
#plt.axis([0.8,1.2,1.4,1.9])
ax.tick_params(axis='both', which='major', labelsize=12)
ax.tick_params(axis='both', which='minor', labelsize=8)

#ax.xaxis.set_major_locator(MultipleLocator(0.2e8))
#ax.xaxis.set_major_formatter(FormatStrFormatter('%d'))
# For the minor ticks, use no labels; default NullFormatter.
ax.xaxis.set_minor_locator(AutoMinorLocator())
ax.yaxis.set_minor_locator(AutoMinorLocator())
plt.savefig('time_comparison_med_run3.pdf')

plt.show()

# ----------------- cold --------------------------
fig, ax = plt.subplots(figsize=[8, 5])
j=0
Ts = {}
Tign = {}
for i in cols:
    Ts[f"{i}"] = 10**Temp_data_cold[f'{names[j]}'].transpose()[i, :]
    Tign[f"{i}"] = np.array(D.Tign(ycol_data_cold[f'{names[j]}'] / 1e8, 10**Temp_data_cold[f'{names[j]}'].transpose()[i,:], rho_data_cold[f'{names[j]}']))
plt.plot(ycol_data_cold[f'{names[j]}'][:-1]/1e8, Tign[f"{i}"]/1e8, ls="--", label="ignition", color="k")

for j in range(0,4):
    ncols = 10
    cols = np.arange(0, D.Nx, (D.Nx + 1) / ncols, dtype=int)
    cols2 = cols * D.dx
    # get column depths, temperatures and ignition temperatures for these columns
    Ts = {}
    
    for i in cols:
        Ts[f"{i}"] = 10**Temp_data_cold[f'{names[j]}'].transpose()[i, :]
    i=9
    plt.plot(
        ycol_data_cold[f'{names[j]}'][1:]/1e8, Ts[f"{cols[i]}"]/1e8, color=c[j],ls='-'
    ) #label=f"column {cols2[i]}/{D.Lx}"
    i = 0
    plt.plot(
            ycol_data_cold[f'{names[j]}'][1:]/1e8, Ts[f"{cols[i]}"]/1e8, color=c[j], label = f'{names[j]}, cold', ls = '--'
        #label=r'$T_{HS}=1.5\times10^8$ K, pole', ls='-.'
        )



plt.legend(loc="best",fontsize=10, ncol=2)
# plt.xscale("log")
# plt.yscale("log")
plt.xlabel(r"$y$ (10$^8$ g cm$^{-2}$)",fontsize=12)
plt.ylabel("$T$ (10$^8$ K)", fontsize=12)
plt.axis([-0.2,3.8,-0.2,2.5])
#plt.axis([0.8,1.2,1.4,1.9])
ax.tick_params(axis='both', which='major', labelsize=12)
ax.tick_params(axis='both', which='minor', labelsize=8)

#ax.xaxis.set_major_locator(MultipleLocator(0.2e8))
#ax.xaxis.set_major_formatter(FormatStrFormatter('%d'))
# For the minor ticks, use no labels; default NullFormatter.
ax.xaxis.set_minor_locator(AutoMinorLocator())
ax.yaxis.set_minor_locator(AutoMinorLocator())

plt.savefig('time_comparison_cold_run3.pdf')
plt.show()

# %%
# def get_ignition(self, ycol, T):
import color
c = color.IsoColorBlind(4)
# now plot
fig, ax = plt.subplots(figsize=[8, 5])

#-------------------------------------------------------
# # define columns to plot:
# ncols = 10
# cols = np.arange(0, D.Nx, (D.Nx + 1) / ncols, dtype=int)
# cols2 = cols * D.dx
# # get column depths, temperatures and ignition temperatures for these columns
# Ts = {}
# Tign = {}
# for i in cols:
#     Ts[f"{i}"] = 10**T2.transpose()[i, :]
#     Tign[f"{i}"] = np.array(D.Tign(ycol2 / 1e8, 10**T2.transpose()[i,:], rhovals2))
# plt.plot(ycol2[:-1]/1e8, Tign[f"{i}"]/1e8, ls="--", label="ignition", color="k")
# i=9
# plt.plot(
#     ycol2[1:]/1e8, Ts[f"{cols[i]}"]/1e8, color=c[1],ls='-'
# ) #label=f"column {cols2[i]}/{D.Lx}"
# i = 0
# plt.plot(
#         ycol2[1:]/1e8, Ts[f"{cols[i]}"]/1e8, color=c[1], label=r'$T_{HS}=2\times10^8$ K, pole', ls='-.'
#     )

#-------------------------------------------------------
#-------------------------------------------------------
# define columns to plot:
ncols = 10
cols = np.arange(0, D.Nx, (D.Nx + 1) / ncols, dtype=int)
cols2 = cols * D.dx
# get column depths, temperatures and ignition temperatures for these columns
Ts = {}
Tign = {}
for i in cols:
    Ts[f"{i}"] = 10**T6.transpose()[i, :]
    Tign[f"{i}"] = np.array(D.Tign(ycol2 / 1e8, 10**T2.transpose()[i,:], rhovals2))
plt.plot(ycol2[:-1]/1e8, Tign[f"{i}"]/1e8, ls="--", label="ignition", color="k")
i=9
plt.plot(
    ycol2[1:]/1e8, Ts[f"{cols[i]}"]/1e8, color=c[0],ls='-'
) #label=f"column {cols2[i]}/{D.Lx}"
i = 0
plt.plot(
        ycol2[1:]/1e8, Ts[f"{cols[i]}"]/1e8, color=c[0], label=r'$T_{HS}=1.5\times10^8$ K, pole', ls='-.'
    )

#-------------------------------------------------------
# define columns to plot:
ncols = 10
cols = np.arange(0, D.Nx, (D.Nx + 1) / ncols, dtype=int)
cols2 = cols * D.dx
# get column depths, temperatures and ignition temperatures for these columns
for i in cols:
    Ts[f"{i}"] = 10**T1.transpose()[i, :]
    Tign[f"{i}"] = np.array(D.Tign(ycol2 / 1e8, T1.transpose()[i,:], rhovals2))
# plt.plot(ycol2[:-1]/1e8, Tign[f"{i}"]/1e8, ls="--", label="ignition", color="k")


i=9
plt.plot(
    ycol2[1:]/1e8, Ts[f"{cols[i]}"]/1e8, color=c[1],ls='-'
) #label=f"column {cols2[i]}/{D.Lx}"
i = 0
plt.plot(
        ycol2[1:]/1e8, Ts[f"{cols[i]}"]/1e8, color=c[1], label=r'$T_{HS} = 1\times10^8$ K, pole', ls='-.'
    )

plt.scatter(1e8,1e8,color=c[0])

#-------------------------------------------------------
# # define columns to plot:
# ncols = 10
# cols = np.arange(0, D.Nx, (D.Nx + 1) / ncols, dtype=int)
# cols2 = cols * D.dx
# # get column depths, temperatures and ignition temperatures for these columns
# Ts = {}
# Tign = {}
# for i in cols:
#     Ts[f"{i}"] = 10**T3.transpose()[i, :]

# i= 9
# plt.plot(
#     ycol[1:]/1e8, Ts[f"{cols[i]}"]/1e8, color=c[2],ls='-',lw=0.8
# ) #label=f"column {cols2[i]}/{D.Lx}"
# i = 0
# plt.plot(
#         ycol[1:]/1e8, Ts[f"{cols[i]}"]/1e8, color=c[2],lw=0.8, ls='-.', label=r'$T_{HS}=2\times10^8$ K, equator'
#     )
#-------------------------------------------------------

#-------------------------------------------------------
# define columns to plot:
ncols = 10
cols = np.arange(0, D.Nx, (D.Nx + 1) / ncols, dtype=int)
cols2 = cols * D.dx
# get column depths, temperatures and ignition temperatures for these columns
Ts = {}
Tign = {}
for i in cols:
    Ts[f"{i}"] = 10**T4.transpose()[i, :]
#     Tign[f"{i}"] = D.Tign(ycol / 1e8)

i= 9
plt.plot(
    ycol[1:]/1e8, Ts[f"{cols[i]}"]/1e8, color=c[2],ls='-',lw=1.2
) #label=f"column {cols2[i]}/{D.Lx}"
i = 0
plt.plot(
        ycol[1:]/1e8, Ts[f"{cols[i]}"]/1e8, color=c[2],lw=1.2, ls='-.', label=r'$T_{HS}=1.5\times10^8$ K, equator'
    )

#-------------------------------------------------------

#-------------------------------------------------------
#define columns to plot:
ncols = 10
cols = np.arange(0, D.Nx, (D.Nx + 1) / ncols, dtype=int)
cols2 = cols * D.dx
# get column depths, temperatures and ignition temperatures for these columns
Ts = {}
Tign = {}
for i in cols:
    Ts[f"{i}"] = 10**T5.transpose()[i, :]

i= 9
plt.plot(
    ycol[1:]/1e8, Ts[f"{cols[i]}"]/1e8, color=c[3],ls='-',lw=1.2
) #label=f"column {cols2[i]}/{D.Lx}"
i = 0
plt.plot(
        ycol[1:]/1e8, Ts[f"{cols[i]}"]/1e8, color=c[3], ls='-.', lw=1.2,label=r'$T_{HS}=1\times10^8$ K, equator'
    )


# inset axis to zoom in on bottom:

# inset axes....
# axins = ax.inset_axes([0.5, 0.35, 0.25, 0.25])
# for i in range(len(cols)):
#     axins.plot(ycol, Ts[f"{cols[i]}"], color=c[i])
# # sub region of the original image
# x1, x2, y1, y2 = 2e7, 3.5e7, 4e7, 4.8e7
# axins.set_xlim(x1, x2)
# axins.set_ylim(y1, y2)
# axins.set_xscale("log")
# axins.set_yscale("log")
# # axins.set_xticklabels('')
# # axins.set_yticklabels('')

# ax.indicate_inset_zoom(axins, label=None)
hotspoty = np.arange(
    int((D.Nx) / 2 - D.hsize / 2), int((D.Nx + 1) / 2 + D.hsize / 2)
)

plt.legend(loc="best",fontsize=10, ncol=2)
#plt.xscale("log")
#plt.yscale("log")
plt.xlabel(r"$y$ (10$^8$ g cm$^{-2}$)",fontsize=12)
plt.ylabel("$T$ (10$^8$ K)", fontsize=12)
plt.axis([-0.2,3.8,-0.2,2.5])
ax.tick_params(axis='both', which='major', labelsize=12)
ax.tick_params(axis='both', which='minor', labelsize=8)

#ax.xaxis.set_major_locator(MultipleLocator(0.2e8))
#ax.xaxis.set_major_formatter(FormatStrFormatter('%d'))
# For the minor ticks, use no labels; default NullFormatter.
ax.xaxis.set_minor_locator(AutoMinorLocator())
ax.yaxis.set_minor_locator(AutoMinorLocator())

plt.savefig('paperplots/mdot10_ign_qb01_comparison_linearscale.pdf')
plt.show()
plt.close()
